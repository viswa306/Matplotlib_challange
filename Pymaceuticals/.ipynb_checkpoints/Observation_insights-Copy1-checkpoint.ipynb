# %% [markdown]
# ## Observations and Insights

# %%
# %matplotlib notebook

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_mousestudy_df = pd.merge(mouse_metadata,study_results,
                                 how='outer', on='Mouse ID')

# Display the data table for preview
combined_mousestudy_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
mice_count=mouse_metadata['Mouse ID'].count()
mice_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint
duplicate_mouse_id=combined_mousestudy_df[["Mouse ID","Timepoint"]]
duplicate_mouse_id = duplicate_mouse_id[duplicate_mouse_id.duplicated(["Mouse ID","Timepoint"], keep="first")]
print(duplicate_mouse_id)
# Out:
#     Mouse ID  Timepoint
# 909     g989          0
# 911     g989          5
# 913     g989         10
# 915     g989         15
# 917     g989         20

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_mouse_id = duplicate_mouse_id.drop_duplicates(subset = "Mouse ID", keep = 'first')
duplicate_mouse_id_all_data = pd.merge(duplicate_mouse_id,combined_mousestudy_df, on='Mouse ID',how ='inner')
duplicate_mouse_id_all_data
# Out:
#    Mouse ID  Timepoint_x Drug Regimen     Sex  Age_months  Weight (g)  \
# 0      g989            0     Propriva  Female          21          26
# 1      g989            0     Propriva  Female          21          26
# 2      g989            0     Propriva  Female          21          26
# 3      g989            0     Propriva  Female          21          26
# 4      g989            0     Propriva  Female          21          26
# 5      g989            0     Propriva  Female          21          26
# 6      g989            0     Propriva  Female          21          26
# 7      g989            0     Propriva  Female          21          26
# 8      g989            0     Propriva  Female          21          26
# 9      g989            0     Propriva  Female          21          26
# 10     g989            0     Propriva  Female          21          26
# 11     g989            0     Propriva  Female          21          26
# 12     g989            0     Propriva  Female          21          26
#
#     Timepoint_y  Tumor Volume (mm3)  Metastatic Sites
# 0             0           45.000000                 0
# 1             0           45.000000                 0
# 2             5           48.786801                 0
# 3             5           47.570392                 0
# 4            10           51.745156                 0
# 5            10           49.880528                 0
# 6            15           51.325852                 1
# 7            15           53.442020                 0
# 8            20           55.326122                 1
# 9            20           54.657650                 1
# 10           25           56.045564                 1
# 11           30           59.082294                 1
# 12           35           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df= combined_mousestudy_df.drop_duplicates(subset = "Mouse ID", keep = 'first')
clean_df
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 10       s185    Capomulin  Female           3          17          0
# 20       x401    Capomulin  Female          16          15          0
# 30       m601    Capomulin    Male          22          17          0
# 40       g791     Ramicane    Male          11          16          0
# ...       ...          ...     ...         ...         ...        ...
# 1858     z314     Stelasyn  Female          21          28          0
# 1860     z435     Propriva  Female          12          26          0
# 1863     z581    Infubinol  Female          24          25          0
# 1873     z795     Naftisol  Female          13          29          0
# 1883     z969     Naftisol    Male           9          30          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                   45.0                 0
# 10                  45.0                 0
# 20                  45.0                 0
# 30                  45.0                 0
# 40                  45.0                 0
# ...                  ...               ...
# 1858                45.0                 0
# 1860                45.0                 0
# 1863                45.0                 0
# 1873                45.0                 0
# 1883                45.0                 0
#
# [249 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
clean_df_mousecount=clean_df ['Mouse ID'].count()
clean_df_mousecount
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# standarderror=combined_mousestudy_df.loc[:,"Tumor Volume (mm3)"].sem(axis = 0)
# standarderror
# Out:
# 0.20443585034961495

# %%
# # Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# v_mean=combined_mousestudy_df.groupby('Drug Regimen')["Tumor Volume (mm3)"].mean()

# v_median=combined_mousestudy_df.groupby('Drug Regimen')["Tumor Volume (mm3)"].median()

# v_sd=combined_mousestudy_df.loc[:,"Tumor Volume (mm3)"].std

# v_var=combined_mousestudy_df.loc[:,"Tumor Volume (mm3)"].var()
 
# standarderror=combined_mousestudy_df.loc[:,"Tumor Volume (mm3)"].sem(axis = 0) 
# standarderror

# # This method is the most straighforward, creating multiple series and putting them all together at the end.

# Summary_data = {'Mean':v_mean,'Median':v_median,'variance':v_var,'standard deviation':v_sd,'SEM':standarderror}
# summary_stats=pd.DataFrame(Summary_data )
# summary_stats
# Out:
#                    Mean     Median   variance  standard deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  79.116074            8.894722  0.204436
# Ceftamin      52.591172  51.776157  79.116074            8.894722  0.204436
# Infubinol     52.884795  51.820584  79.116074            8.894722  0.204436
# Ketapril      55.235638  53.698743  79.116074            8.894722  0.204436
# Naftisol      54.331565  52.509285  79.116074            8.894722  0.204436
# Placebo       54.033581  52.288934  79.116074            8.894722  0.204436
# Propriva      52.322552  50.854632  79.116074            8.894722  0.204436
# Ramicane      40.216745  40.673236  79.116074            8.894722  0.204436
# Stelasyn      54.233149  52.431737  79.116074            8.894722  0.204436
# Zoniferol     53.236507  51.818479  79.116074            8.894722  0.204436

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
v_mean = combined_mousestudy_df.groupby('Drug Regimen').mean()['Tumor Volume (mm3)']
v_median=combined_mousestudy_df.groupby('Drug Regimen').median()["Tumor Volume (mm3)"]

v_sd=combined_mousestudy_df.groupby('Drug Regimen').std()["Tumor Volume (mm3)"]

v_var=combined_mousestudy_df.groupby('Drug Regimen').var()["Tumor Volume (mm3)"]
standarderror=combined_mousestudy_df.groupby('Drug Regimen').sem()["Tumor Volume (mm3)"]
standarderror
 # This method is the most straighforward, creating multiple series and putting them all together at the end.

Summary_data = {'Tumor_volume_Mean':v_mean,
                'Tumor_volume_Median':v_median,
                'Tumor_volume_variance':v_var,
                'Tumor_volume_standard deviation':v_sd,
                'Tumor_volume_SEM':standarderror}
summary_stats=pd.DataFrame(Summary_data )
summary_stats
# Out:
#               Tumor_volume_Mean  Tumor_volume_Median  Tumor_volume_variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor_volume_standard deviation  Tumor_volume_SEM
# Drug Regimen
# Capomulin                            4.994774          0.329346
# Ceftamin                             6.268188          0.469821
# Infubinol                            6.567243          0.492236
# Ketapril                             8.279709          0.603860
# Naftisol                             8.134708          0.596466
# Placebo                              7.821003          0.581331
# Propriva                             6.507770          0.512884
# Ramicane                             4.846308          0.320955
# Stelasyn                             7.710419          0.573111
# Zoniferol                            6.966589          0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
mouse_summary_stats=combined_mousestudy_df.groupby(['Drug Regimen']).agg(
                                                   Tumor_volume_mean =('Tumor Volume (mm3)','mean'),
                                                    Tumor_volume_median =('Tumor Volume (mm3)', 'median'),
                                                    Tumor_volume_variance  =('Tumor Volume (mm3)', 'var'),
                                                 Tumor_volume_standdev  = ('Tumor Volume (mm3)','std') ,
                                                    Tumor_volume_sem  =('Tumor Volume (mm3)','sem')                  
                                                      ) 
                                                
mouse_summary_stats
# Out:
#               Tumor_volume_mean  Tumor_volume_median  Tumor_volume_variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor_volume_standdev  Tumor_volume_sem
# Drug Regimen
# Capomulin                  4.994774          0.329346
# Ceftamin                   6.268188          0.469821
# Infubinol                  6.567243          0.492236
# Ketapril                   8.279709          0.603860
# Naftisol                   8.134708          0.596466
# Placebo                    7.821003          0.581331
# Propriva                   6.507770          0.512884
# Ramicane                   4.846308          0.320955
# Stelasyn                   7.710419          0.573111
# Zoniferol                  6.966589          0.516398

# %%
df3=combined_mousestudy_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean","median","var","std","sem"]})
df3
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Filter the DataFrame down only to those columns to chart
mouseid_drug = clean_df[["Drug Regimen","Mouse ID","Tumor Volume (mm3)"]]

# Set the index to be "mouse id" so they will be used as labels
mouseid_drug = mouseid_drug.set_index("Drug Regimen")

mouseid_drug
# Out:
#              Mouse ID  Tumor Volume (mm3)
# Drug Regimen
# Ramicane         k403                45.0
# Capomulin        s185                45.0
# Capomulin        x401                45.0
# Capomulin        m601                45.0
# Ramicane         g791                45.0
# ...               ...                 ...
# Stelasyn         z314                45.0
# Propriva         z435                45.0
# Infubinol        z581                45.0
# Naftisol         z795                45.0
# Naftisol         z969                45.0
#
# [249 rows x 2 columns]

# %%
# # Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
# mouse_study_plot= mouseid_drug.plot(kind="bar",figsize=(70,5))

# # PandasPlot.set_xticklabels() can be used to set the tick labels as well
# mouse_study_plot.set_xticklabels(clean_df['Mouse ID'], rotation=45)

# # Set a title for the chart
# plt.title("Total number of mice for each Treatment")

# plt.show()
# plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
#Each Treatment

each_treatment= combined_mousestudy_df.groupby('Drug Regimen')["Mouse ID"].count()

each_treatment
each_drug_treated=pd.DataFrame(each_treatment)
each_drug_treated
# Out:
#               Mouse ID
# Drug Regimen
# Capomulin          230
# Ceftamin           178
# Infubinol          178
# Ketapril           188
# Naftisol           186
# Placebo            181
# Propriva           161
# Ramicane           228
# Stelasyn           181
# Zoniferol          182

# %%
# # Filter the DataFrame down only to those columns to chart
# mouseid_drug = clean_df[["Drug Regimen","Tumor Volume (mm3)","Mouse ID",]]

# # Set the index to be "State" so they will be used as labels
# mouseid_drug = mouseid_drug.set_index("Drug Regimen")

# mouseid_drug
# Out:
#               Tumor Volume (mm3) Mouse ID
# Drug Regimen
# Ramicane                    45.0     k403
# Capomulin                   45.0     s185
# Capomulin                   45.0     x401
# Capomulin                   45.0     m601
# Ramicane                    45.0     g791
# ...                          ...      ...
# Stelasyn                    45.0     z314
# Propriva                    45.0     z435
# Infubinol                   45.0     z581
# Naftisol                    45.0     z795
# Naftisol                    45.0     z969
#
# [249 rows x 2 columns]

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
mouse_study_plot=each_drug_treated.plot(kind="bar",figsize=(5,5))

# # PandasPlot.set_xticklabels() can be used to set the tick labels as well
mouse_study_plot.set_xticklabels(clean_df['Drug Regimen'])

# # Set a title for the chart
plt.title("Total number of Mice for each Treatment")
plt.ylabel("Mouse count")
plt.legend()
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
#Drug_Tratment =clean_df["Drug Regimen"]
# Set x axis and tick locations
x_axis = np.arange(len(each_drug_treated))
tick_locations = [value for value in x_axis]

# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(10,3))
plt.bar(x_axis,each_drug_treated["Mouse ID"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations,clean_df["Drug Regimen"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ([<matplotlib.axis.XTick at 0x29b98cbfc08>,
#   <matplotlib.axis.XTick at 0x29b99b58a88>,
#   <matplotlib.axis.XTick at 0x29b99b589c8>,
#   <matplotlib.axis.XTick at 0x29b99b3bec8>,
#   <matplotlib.axis.XTick at 0x29b98adcb88>,
#   <matplotlib.axis.XTick at 0x29b98adc288>,
#   <matplotlib.axis.XTick at 0x29b99b47408>,
#   <matplotlib.axis.XTick at 0x29b99b47a08>,
#   <matplotlib.axis.XTick at 0x29b98a0e808>,
#   <matplotlib.axis.XTick at 0x29b98ae7508>],
#  <a list of 10 Text xticklabel objects>)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# #Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
